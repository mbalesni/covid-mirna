# %% [markdown]
# The Expect value (E) is a parameter that describes the number of hits one can "expect" to see by chance when searching a database of a particular size. It decreases exponentially as the Score (S) of the match increases. Essentially, the E value describes the random background noise. For example, an E value of 1 assigned to a hit can be interpreted as meaning that in a database of the current size one might expect to see 1 match with a similar score simply by chance.

# %%
import pandas as pd
#got these from mirbase, evalue cutoff 5
df_mirnafold = pd.read_csv('mirnafold_overlap_with_knownmirnas.csv', sep = '\t')

# %%
ids_mirnafold = set(df_mirnafold.ID.to_list())
ids_mirnafold
# Out:
# {'ame-miR-6038-5p',
#  'cja-miR-548g',
#  'cja-miR-9915',
#  'dqu-miR-6038-5p',
#  'hsa-miR-1272',
#  'hsa-miR-576-3p',
#  'hsa-miR-576-5p',
#  'lja-miR11156-5p',
#  'mml-miR-576-3p',
#  'mml-miR-576-5p',
#  'pca-miR-6038-5p',
#  'ppe-miR6290',
#  'ppy-miR-576-3p',
#  'ppy-miR-576-5p',
#  'ptr-miR-1272',
#  'ptr-miR-576',
#  'tca-miR-6007-3p'}

# %%
#from cuilab.cn

results_cuilab_mirnafold = pd.read_csv('cuilab_result_mirnafold.csv')
results_cuilab_mirnafold
# Out:
#     miRNA name                       Evidence Code               Disease name  \
# 0  hsa-mir-576  circulation_biomarker_diagnosis_ns                     Glioma
# 1  hsa-mir-576                               other         Carcinoma, Bladder
# 2  hsa-mir-576                               other                   Melanoma
# 3  hsa-mir-576                         target gene          Bladder Neoplasms
# 4  hsa-mir-576                  therapeutic target           Breast Neoplasms
# 5  hsa-mir-576                tissue_expression_ns  Carcinoma, Hepatocellular
# 6  hsa-mir-576                tissue_expression_up       Colorectal Carcinoma
#
#        PMID                                        Description Causality
# 0  24858071  miRNA profile of the peripheral blood may serv...        NO
# 1  28338199  MiR-576-3p is a novel marker correlated with p...        NO
# 2  30197759  miR-193b and miR-30c-1* inhibit, whereas miR-5...        NO
# ...

# %%
#http://bioinfo.life.hust.edu.cn/miRNASNP/#!/mutation_summary
results_bioinfo_mirnafold = pd.read_csv('bioinfo_result_mirnafold.csv')
results_bioinfo_mirnafold
# Out:
#       Pre-miRNA   Mutation ID        Position Ref/Alt  \
# 0  hsa-mir-1272   COSN1081476  chr15:64762412     G/A
# 1  hsa-mir-1272   COSN1081475  chr15:64762480     T/C
# 2  hsa-mir-1272  COSN19395611  chr15:64762483     C/T
# 3  hsa-mir-1272  COSN26991829  chr15:64762497     G/A
# 4  hsa-mir-1272   COSN4710431  chr15:64762497     G/A
# 5  hsa-mir-1272   COSN2378591  chr15:64762506     T/C
#
#                                     Disease     Region  Mature miRNA    G  \
# 0                     endometrium;carcinoma  pre-miRNA             -  2.6
# 1                     endometrium;carcinoma     Mature  hsa-miR-1272  0.0
# 2                        prostate;carcinoma     Mature  hsa-miR-1272  5.5
# 3  large intestine;carcinoma(PMID:27149842)  pre-miRNA             -  2.5
# 4                     endometrium;carcinoma  pre-miRNA             -  2.5
# 5                            lung;carcinoma  pre-miRNA             -  1.2
#
#     Exp  Source  Unnamed: 10
# 0  down  COSMIC          NaN
# ...

# %%
df_vmir = pd.read_csv('vmir_overlap_with_knownmirnas.csv',sep = '\t')

ids_vmir = set(df_vmir.ID.to_list())
ids_vmir
# Out:
# {'ahy-miR408-5p',
#  'dme-miR-994-3p',
#  'dps-miR-994-3p',
#  'dvi-miR-994-3p',
#  'hbr-miR408b',
#  'hpo-miR-10071-3p',
#  'hsa-miR-4732-5p',
#  'hsa-miR-7849-3p',
#  'pab-miR11483',
#  'ppc-miR-8364g-3p',
#  'sme-miR-7b-3p'}

# %%
#from cuilab.cn

results_cuilab_vmir = pd.read_csv('cuilab_result_vmir.csv')
results_cuilab_vmir
# Out:
#      miRNA name                         Evidence Code  \
# 0  hsa-mir-4732  circulation_biomarker_diagnosis_down
# 1  hsa-mir-4732    circulation_biomarker_diagnosis_ns
# 2  hsa-mir-4732                                 other
# 3  hsa-mir-4732                           target gene
#
#                    Disease name      PMID  \
# 0  Systemic Lupus Erythematosus  29873187
# 1           Colitis, Ulcerative  26569605
# 2             Gastric Neoplasms  24317477
# 3        Neoplasms [unspecific]  23886136
#
#                                          Description Causality
# 0  Although the levels of many miRNAs were unaffe...        NO
# 1  This is the first study to show the differenti...        NO
# 2  Relapse-associated microRNA in gastric cancer ...        NO
# 3  From our findings we propose designing further...        NO

# %%
results_bioinfo_vmir = pd.read_csv('bioinfo_result_vmir.csv')
results_bioinfo_vmir
# Out:
#       Pre-miRNA   Mutation ID        Position Ref/Alt             Disease  \
# 0  hsa-mir-7849  COSN26261358  chr4:146408636     A/C  prostate;carcinoma
#
#       Region Mature miRNA    G Exp  Source
# 0  pre-miRNA            -  0.0  up  COSMIC
